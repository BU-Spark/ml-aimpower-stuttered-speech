# %% [markdown]
# # Whisper Model (Large & Small) Evaluation On Stuttering

# %% [markdown]
# 1. Turn original transcripts into dataframes
# 2. Read generated transcript dataframes
# 3. Get Error & Stuttering count
# 4. Get Error & Stuttering Type ==> show which Stuttering type is more prone to error
# 5. Calculate Correlation Score
# 6. Generate Heatmap
# 7. Summarize Trend
#
# ***
#
# ### Error Metrics
# 1. Net / Total Word Error Rate
# 2. Word Error Rate Specific After Cleaning other Stuttering Type Annotations

# %% [markdown]
# ***

# %% [markdown]
# ## Using Custom Kernel on SCC
#
# SCC sometimes has the problem with installed library not importable [`module not found` error], this is an alternative.
#
# Assuming you have a conda environment created, you would do the following:
# 1. `conda install -c anaconda ipykernel`
# 2. `python -m ipykernel install --user --name=<env name>`
# 3. If the new kernel cannot be found, relaunch a new SCC instance
#
# **Remember to switch to the conda env kernel**

# %%
ds_transcript_path = "/projectnb/ds549/projects/AImpower/datasets/updated_annotation_deid_full"

# %%
# !pip install pandas numpy scipy tqdm
# Out:
# Requirement already satisfied: pandas in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: scipy in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: tqdm in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /projectnb/ds549/students/wycheng/learner-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ---

# %% [markdown]
# ## Word Error Rate
#
# Objectives:
# * split sequence into characters
# * count:
#     * deletion: missing words
#     * substitutions: wrongly recognized words
#     * insertions: extra words

# %%
def wer(candidate, reference):
    """
    Parameter(s)
    ------------
    candidate ==> generated transcript
    reference ==> dataset transcript
    """
    
    candidate_tokens = list(candidate)
    reference_tokens = list(reference)
    
    cand_len = len(candidate_tokens)
    ref_len = len(reference_tokens)
    
    dist_mat = np.zeros((ref_len, cand_len), dtype=int)
    
    for i in range(ref_len):
        dist_mat[i][0] = i
    for j in range(cand_len):
        dist_mat[0][j] = j
        
    for i in range(1, ref_len):
        for j in range(1, cand_len):
            if (candidate_tokens[j - 1] == reference_tokens[i - 1]):
                cost = 0
            else:
                cost = 1
                
            dist_mat[i][j] = min(
                dist_mat[i-1][j] + 1,
                dist_mat[i][j-1] + 1,
                dist_mat[i-1][j-1] + cost
            )
            # print(dist_mat)
            
    wer = dist_mat[-1][-1] / len(reference_tokens)
    return wer

# %% [markdown]
# ***

# %% [markdown]
# ## Imports and Data Ingestion (Whisper Large)

# %%
import pandas as pd
import numpy as np
import scipy
import os
from tqdm import tqdm
import re
import sys

# %%
net_data = pd.DataFrame(columns=["Filename", "Start_time", "End_time", "Transcript"]) 
net_aigenerated_data_whisper_large = pd.read_csv("/projectnb/ds549/projects/AImpower/datasets/generated-transcripts/Whisper_large.csv", delimiter=",")

del net_aigenerated_data_whisper_large[net_aigenerated_data_whisper_large.columns[0]]

# %%
for folder in os.listdir(ds_transcript_path):
    if folder == "command_stats.xlsx" or folder == "command_stats.csv":
        continue
    for audio_sample in os.listdir(os.path.join(ds_transcript_path, f"{folder}")):
        if ("_A.txt" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_A")])
        if ("_B.txt" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_B")])
        if ("P" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"P{folder}")])
# Out:
# /scratch/923464.1.academic/ipykernel_2708003/4285821246.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_A")])

# %%
mask_pattern = r"\<.*?\>"
repetition_pattern = r"\[.*?\]"
annotation_pattern = r"/\w"


net_data = net_data.assign(Cleaned_Transcript=net_data['Transcript'].apply(lambda x: re.sub(annotation_pattern, "", re.sub(repetition_pattern, "", re.sub(mask_pattern, "", x)))))
net_data = net_data.assign(Stutterance_Count=net_data['Transcript'].apply(lambda x: len(re.findall(mask_pattern, x)) + len(re.findall(repetition_pattern, x)) + len(re.findall(annotation_pattern, x))))

# %%
net_data
# Out:
#     Filename  Start_time  End_time  \
# 0    D0045_A      48.330    58.020
# 1    D0045_A      58.900    72.140
# 2    D0045_A      74.100    81.260
# 3    D0045_A      84.930    86.320
# 4    D0045_A     100.950   113.700
# ..       ...         ...       ...
# 135    P0030    3202.732  3213.472
# 136    P0030    3216.222  3221.042
# 137    P0030    3225.732  3236.142
# 138    P0030    3240.652  3253.172
# 139    P0030    3256.672  3264.012
#
#                                             Transcript  \
# 0        嗯，我[我/b我]现在已经工作了，我是/p一八年毕业的，然后我的专业是/p国际经济与贸易。
# 1    然后我现在嗯/i/p我现在的工作是/p[是]在/p[是在]<人民银行>，但是这个工作就是/p...
# 2                    嗯/i/p然后我平常的爱好是/p比较喜欢看电影，然后还喜欢打网球。
# 3                                     嗯/i<overlap>结束了。
# 4    嗯，这个就是它[它]不是银行系统，然后它然/r后那个之所以不干，是因为就是这个，嗯/i就是现...
# ..                                                 ...
# 135                                单曲循环歌曲最[最最]爱的为何没结果。
# 136                                      来[来]一首朴/p树的歌。
# 137                         搜[搜/r/b搜]索小灿的多/p年/p/r/b以后。
# 138                                播放半吨/b/r/p孙弟歌孙兄弟的歌。
# 139                                    单/p曲循环歌/p曲你的灵魂。
#
#                                     Cleaned_Transcript  Stutterance_Count
# 0                  嗯，我现在已经工作了，我是一八年毕业的，然后我的专业是国际经济与贸易。                  4
# 1                     然后我现在嗯我现在的工作是在，但是这个工作就是可能快要就不干了。                  8
# 2                          嗯然后我平常的爱好是比较喜欢看电影，然后还喜欢打网球。                  3
# 3                                                嗯结束了。                  2
# 4    嗯，这个就是它不是银行系统，然后它然后那个之所以不干，是因为就是这个，嗯就是现在人民银行的县...                  4
# ..                                                 ...                ...
# 135                                    单曲循环歌曲最爱的为何没结果。                  1
# 136                                           来一首朴树的歌。                  2
# 137                                         搜索小灿的多年以后。                  7
# 138                                      播放半吨孙弟歌孙兄弟的歌。                  3
# 139                                        单曲循环歌曲你的灵魂。                  2
#
# [37250 rows x 6 columns]

# %%
net_aigenerated_data_whisper_large
# Out:
#       Filename   Start_time     End_time  \
# 0      D0001_A  2081.540000  2109.650000
# 1      D0001_A   790.130000   796.580000
# 2      D0001_A  1562.083518  1586.220000
# 3      D0001_A  2016.780000  2035.673559
# 4      D0001_A  1682.670000  1709.110000
# ...        ...          ...          ...
# 37248    P0070  2586.616000  2589.346000
# 37249    P0070  2782.496000  2783.706000
# 37250    P0070  2995.296000  2998.116000
# 37251    P0070  2604.066000  2606.656000
# 37252    P0070  2434.606000  2436.576000
#
#                                            Whisper_large
# 0      我说出来就比较的需要时间然后识别的他等你一会儿你那个话还没有说完还没有说出来的话他就取消了也...
# 1                                               第四句有我说的话
# 2         这部剧评分是不怎么好的因为评论区的那些人都在说男二号好惨的那个就那么情绪但是就一直输给男主角
# 3                          很精准迅飞语音还是迅飞出手来的我记得他是叫迅飞我之前就是他
# 4      那个是叫什么来的我忘了就是出现了另一个人然后呢他就射了一把箭然后就把那个男二号给绑杀了就是可...
# ...                                                  ...
# 37248                                         三曲循环歌曲这样而已
# 37249                                              杨幂的电影
# 37250                                       你好米亚今天柴油价怎么样
# 37251                                       单曲循环歌曲 琉璃光之歌
# 37252                                            導航到隆城民院
#
# [37253 rows x 4 columns]

# %% [markdown]
# **Now we have raw data of all audio transcriptions from datasets [updated_annotation_deid_full] in `net_data` and AI predicted transcriptions in `net_aigenerated_data_whisper_large`**

# %% [markdown]
# ***

# %% [markdown]
# ## Whisper Large WER Analysis

# %%
na_count_large = 0
na_count_cleaned = 0
for index, row in tqdm(net_aigenerated_data_whisper_large.iterrows(), total=len(net_aigenerated_data_whisper_large)):
    
    mask_large = (
        (net_aigenerated_data_whisper_large["Filename"] == row["Filename"]) &
        (net_aigenerated_data_whisper_large["Start_time"] == row["Start_time"])
    )

    mask_net = (
        (net_data["Filename"] == row["Filename"]) &
        (net_data["Start_time"] == row["Start_time"])
    )

    
    large_row = net_aigenerated_data_whisper_large.loc[mask_large]
    net_row = net_data.loc[mask_net]

    # print(large_row)
    # print('\n\n\n\n')
    # print(net_row)
    
    if large_row.empty or net_row.empty:
        print("Skipping: One of the rows is empty.")
        continue
        
    whisper_large = large_row["Whisper_large"].values[0]
    cleaned_transcript = net_row["Cleaned_Transcript"].values[0]
    
    if pd.isna(whisper_large) or not isinstance(whisper_large, str):
        print("Skipping due to missing or non-string Whisper_large.")
        na_count_large = na_count_large + 1
        continue
    if pd.isna(cleaned_transcript) or not isinstance(cleaned_transcript, str):
        print("Skipping due to missing or non-string Cleaned_Transcript.")
        na_count_cleaned = na_count_cleaned + 1
        continue

    try:
        
        wer_value = wer(whisper_large, cleaned_transcript)
        
        net_aigenerated_data_whisper_large.loc[mask_large, "WER"] = wer_value
        
        stutterance_count = net_row["Stutterance_Count"].values[0]
        net_aigenerated_data_whisper_large.loc[mask_large, "Stutterance_Count"] = stutterance_count

        # Verify assignment
        # print(f'Assigned Stutterance_Count: {stutterance_count}')
        # print(net_aigenerated_data_whisper_large.loc[mask_large, "Stutterance_Count"])

    except Exception as e:
        print(f'ERROR: {e}')
        print('Occurred with the following data:')
        print(large_row)
        print(net_row)
        
net_aigenerated_data_whisper_large = net_aigenerated_data_whisper_large.assign(NA_Count=na_count_large)
net_aigenerated_data_whisper_large = net_aigenerated_data_whisper_large.assign(NA_Cleaned_Count=na_count_cleaned)
# Out:
#   5%|▍         | 1845/37253 [00:13<04:02, 145.82it/s]
# Skipping: One of the rows is empty.
#  13%|█▎        | 4712/37253 [00:33<03:38, 148.67it/s]
# Skipping due to missing or non-string Whisper_large.
#  15%|█▌        | 5615/37253 [00:39<03:33, 147.99it/s]
# Skipping due to missing or non-string Whisper_large.
#  16%|█▌        | 5802/37253 [00:41<03:59, 131.21it/s]
# Skipping due to missing or non-string Whisper_large.
#  17%|█▋        | 6230/37253 [00:44<03:30, 147.72it/s]
# Skipping due to missing or non-string Whisper_large.
#  28%|██▊       | 10491/37253 [01:13<03:13, 138.11it/s]
# Skipping: One of the rows is empty.
#  36%|███▌      | 13327/37253 [01:33<02:43, 146.25it/s]
# Skipping due to missing or non-string Whisper_large.
#  44%|████▍     | 16509/37253 [01:54<02:07, 163.03it/s]
# Skipping due to missing or non-string Whisper_large.
#  91%|█████████▏| 34065/37253 [03:39<00:19, 166.87it/s]
# Skipping: One of the rows is empty.
#  92%|█████████▏| 34116/37253 [03:40<00:18, 168.36it/s]
# Skipping: One of the rows is empty.
#  93%|█████████▎| 34593/37253 [03:43<00:15, 168.56it/s]
# Skipping: One of the rows is empty.
# 100%|██████████| 37253/37253 [03:58<00:00, 155.95it/s]

# %%
net_aigenerated_data_whisper_large
# Out:
#       Filename   Start_time     End_time  \
# 0      D0001_A  2081.540000  2109.650000
# 1      D0001_A   790.130000   796.580000
# 2      D0001_A  1562.083518  1586.220000
# 3      D0001_A  2016.780000  2035.673559
# 4      D0001_A  1682.670000  1709.110000
# ...        ...          ...          ...
# 37248    P0070  2586.616000  2589.346000
# 37249    P0070  2782.496000  2783.706000
# 37250    P0070  2995.296000  2998.116000
# 37251    P0070  2604.066000  2606.656000
# 37252    P0070  2434.606000  2436.576000
#
#                                            Whisper_large       WER  \
# 0      我说出来就比较的需要时间然后识别的他等你一会儿你那个话还没有说完还没有说出来的话他就取消了也...  0.247423
# 1                                               第四句有我说的话  0.500000
# 2         这部剧评分是不怎么好的因为评论区的那些人都在说男二号好惨的那个就那么情绪但是就一直输给男主角  0.312500
# 3                          很精准迅飞语音还是迅飞出手来的我记得他是叫迅飞我之前就是他  0.394737
# 4      那个是叫什么来的我忘了就是出现了另一个人然后呢他就射了一把箭然后就把那个男二号给绑杀了就是可...  0.250000
# ...                                                  ...       ...
# 37248                                         三曲循环歌曲这样而已  0.181818
# 37249                                              杨幂的电影  0.166667
# 37250                                       你好米亚今天柴油价怎么样  0.266667
# 37251                                       单曲循环歌曲 琉璃光之歌  0.166667
# 37252                                            導航到隆城民院  0.500000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count
# 0                    1.0         6                 0
# 1                    1.0         6                 0
# 2                   10.0         6                 0
# 3                    7.0         6                 0
# 4                    8.0         6                 0
# ...                  ...       ...               ...
# 37248                0.0         6                 0
# 37249                0.0         6                 0
# 37250                0.0         6                 0
# 37251                0.0         6                 0
# 37252                0.0         6                 0
#
# [37253 rows x 8 columns]

# %%
# net_aigenerated_data_whisper_large.to_csv('net_aigenerated_data_whisper_large_performance_stu.csv', sep=',')

# %% [markdown]
# ***

# %% [markdown]
# ## Visualization of Relationship between Stuttering Count and Word Error Rate (Whisper Large)

# %%
## Load data from csv if starting here

net_aigenerated_data_whisper_large = pd.read_csv('/projectnb/ds549/projects/AImpower/evaluation-whisper/net_aigenerated_data_whisper_large_performance_stu.csv', delimiter=',')

# %%
import matplotlib.pyplot as plt

# %%
## Null value plots

nonnull_count_large = net_aigenerated_data_whisper_large["NA_Count"].count() - net_aigenerated_data_whisper_large.iloc[0]["NA_Count"]
null_count_large = net_aigenerated_data_whisper_large.iloc[0]["NA_Count"]

nonnull_count_cleaned = net_aigenerated_data_whisper_large["NA_Cleaned_Count"].count() - net_aigenerated_data_whisper_large.iloc[0]["NA_Cleaned_Count"]
null_count_cleaned = net_aigenerated_data_whisper_large.iloc[0]["NA_Cleaned_Count"]


data = {
    "NA Values": [null_count_large, null_count_cleaned],
    "Non NA Values": [nonnull_count_large, nonnull_count_cleaned],
}

species = (
    "Whisper Large",
    "Cleaned Ground Truth"
)

width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(2)

for na, count in data.items():
    p = ax.bar(species, count, width, label=na, bottom=bottom)
    bottom += count


ax.set_title("NA value counting", fontsize=16)
ax.set_xlabel("Source", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
ax.legend()
ax.grid(True)

plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["WER"], 
    alpha=0.7  # Handle overlapping points
)

plt.title("WER vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("WER", fontsize=14)
plt.grid(True)
plt.show()

# %%
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

net_aigenerated_data_whisper_large['WER_Binned'] = np.round(net_aigenerated_data_whisper_large['WER'], 2)

grouped_data = net_aigenerated_data_whisper_large.groupby(
    ['Stutterance_Count', 'WER_Binned']
).size().reset_index(name='Count')
heatmap_data = grouped_data.pivot(index='WER_Binned', columns='Stutterance_Count', values='Count').fillna(0)

plt.figure(figsize=(6, 4))
sns.heatmap(
    heatmap_data, cmap='cool', annot=False, fmt='g', cbar=True
)

plt.title("Stutterance Count vs WER (Color = Number of Cases)", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("WER (Binned)", fontsize=14)

plt.show()

# %%
from scipy.stats import spearmanr
rho, p = spearmanr(net_aigenerated_data_whisper_large.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_large.dropna()['WER'])
print(f"p-value = {p}")
print(f"rho = {rho}")
# Out:
# p-value = 5.717674908371687e-196
# rho = -0.15383527583445916

# %% [markdown]
# ***

# %% [markdown]
# ## ROUGE-N/L Scores (Semantic Evaluation) (Whisper Large)

# %%
from rouge_chinese import Rouge
import jieba

# %%
rouge = Rouge()

# %%
print_ = True

for index, row in tqdm(net_aigenerated_data_whisper_large.iterrows(), total=len(net_aigenerated_data_whisper_large)):
    
    mask_large = (
        (net_aigenerated_data_whisper_large["Filename"] == row["Filename"]) &
        (net_aigenerated_data_whisper_large["Start_time"] == row["Start_time"])
    )

    mask_net = (
        (net_data["Filename"] == row["Filename"]) &
        (net_data["Start_time"] == row["Start_time"])
    )

    
    large_row = net_aigenerated_data_whisper_large.loc[mask_large]
    net_row = net_data.loc[mask_net]

    # print(large_row)
    # print('\n\n\n\n')
    # print(net_row)
    
    if large_row.empty or net_row.empty:
        print("Skipping: One of the rows is empty.")
        continue
        
    whisper_large = large_row["Whisper_large"].values[0]
    cleaned_transcript = net_row["Cleaned_Transcript"].values[0]
    
    if pd.isna(whisper_large) or not isinstance(whisper_large, str):
        print("Skipping due to missing or non-string Whisper_large.")
        continue
    if pd.isna(cleaned_transcript) or not isinstance(cleaned_transcript, str):
        print("Skipping due to missing or non-string Cleaned_Transcript.")
        continue

    try:
        
        scores = rouge.get_scores(' '.join(jieba.cut(whisper_large)), ' '.join(jieba.cut(cleaned_transcript)))
        
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge1-precision"] = scores[0]["rouge-1"]["p"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge1-recall"] = scores[0]["rouge-1"]["r"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge1-f1"] = scores[0]["rouge-1"]["f"]
        
        
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge2-precision"] = scores[0]["rouge-2"]["p"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge2-recall"] = scores[0]["rouge-2"]["r"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rouge2-f1"] = scores[0]["rouge-2"]["f"]
        
        
        net_aigenerated_data_whisper_large.loc[mask_large, "rougel-precision"] = scores[0]["rouge-l"]["p"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rougel-recall"] = scores[0]["rouge-l"]["r"]
        net_aigenerated_data_whisper_large.loc[mask_large, "rougel-f1"] = scores[0]["rouge-l"]["f"]
        
        stutterance_count = net_row["Stutterance_Count"].values[0]
        net_aigenerated_data_whisper_large.loc[mask_large, "Stutterance_Count"] = stutterance_count

        if (print_):
            print(net_aigenerated_data_whisper_large)
            print_ = False
        
        # Verify assignment
        # print(f'Assigned Stutterance_Count: {stutterance_count}')
        # print(net_aigenerated_data_whisper_large.loc[mask_large, "Stutterance_Count"])

    except Exception as e:
        print(f'ERROR: {e}')
        print('Occurred with the following data:')
        print(large_row)
        print(net_row)
# Out:
#   0%|          | 0/37253 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Loading model from cache /scratch/923464.1.academic/jieba.cache
# Loading model cost 0.684 seconds.
# Prefix dict has been built successfully.
#   0%|          | 14/37253 [00:00<28:13, 21.99it/s]
#        Unnamed: 0 Filename   Start_time     End_time  \
# 0               0  D0001_A  2081.540000  2109.650000
# 1               1  D0001_A   790.130000   796.580000
# 2               2  D0001_A  1562.083518  1586.220000
# 3               3  D0001_A  2016.780000  2035.673559
# 4               4  D0001_A  1682.670000  1709.110000
# ...           ...      ...          ...          ...
# 37248       37248    P0070  2586.616000  2589.346000
# 37249       37249    P0070  2782.496000  2783.706000
# 37250       37250    P0070  2995.296000  2998.116000
# 37251       37251    P0070  2604.066000  2606.656000
# 37252       37252    P0070  2434.606000  2436.576000
#
#                                            Whisper_large       WER  \
# 0      我说出来就比较的需要时间然后识别的他等你一会儿你那个话还没有说完还没有说出来的话他就取消了也...  0.247423
# 1                                               第四句有我说的话  0.500000
# 2         这部剧评分是不怎么好的因为评论区的那些人都在说男二号好惨的那个就那么情绪但是就一直输给男主角  0.312500
# 3                          很精准迅飞语音还是迅飞出手来的我记得他是叫迅飞我之前就是他  0.394737
# 4      那个是叫什么来的我忘了就是出现了另一个人然后呢他就射了一把箭然后就把那个男二号给绑杀了就是可...  0.250000
# ...                                                  ...       ...
# 37248                                         三曲循环歌曲这样而已  0.181818
# 37249                                              杨幂的电影  0.166667
# 37250                                       你好米亚今天柴油价怎么样  0.266667
# 37251                                       单曲循环歌曲 琉璃光之歌  0.166667
# 37252                                            導航到隆城民院  0.500000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count  WER_Binned  \
# 0                    1.0         6                 0        0.25
# 1                    1.0         6                 0        0.50
# 2                   10.0         6                 0        0.31
# 3                    7.0         6                 0        0.39
# 4                    8.0         6                 0        0.25
# ...                  ...       ...               ...         ...
# 37248                0.0         6                 0        0.18
# 37249                0.0         6                 0        0.17
# 37250                0.0         6                 0        0.27
# 37251                0.0         6                 0        0.17
# 37252                0.0         6                 0        0.50
#
#        rouge1-precision  rouge1-recall  rouge1-f1  rouge2-precision  \
# 0              0.916667       0.868421   0.891892          0.666667
# 1                   NaN            NaN        NaN               NaN
# 2                   NaN            NaN        NaN               NaN
# 3                   NaN            NaN        NaN               NaN
# 4                   NaN            NaN        NaN               NaN
# ...                 ...            ...        ...               ...
# 37248               NaN            NaN        NaN               NaN
# 37249               NaN            NaN        NaN               NaN
# 37250               NaN            NaN        NaN               NaN
# 37251               NaN            NaN        NaN               NaN
# 37252               NaN            NaN        NaN               NaN
#
#        rouge2-recall  rouge2-f1  rougel-precision  rougel-recall  rougel-f1
# 0            0.52459   0.587156          0.888889       0.685714   0.774194
# 1                NaN        NaN               NaN            NaN        NaN
# 2                NaN        NaN               NaN            NaN        NaN
# 3                NaN        NaN               NaN            NaN        NaN
# 4                NaN        NaN               NaN            NaN        NaN
# ...              ...        ...               ...            ...        ...
# 37248            NaN        NaN               NaN            NaN        NaN
# 37249            NaN        NaN               NaN            NaN        NaN
# 37250            NaN        NaN               NaN            NaN        NaN
# 37251            NaN        NaN               NaN            NaN        NaN
# 37252            NaN        NaN               NaN            NaN        NaN
#
# [37253 rows x 19 columns]
#   5%|▍         | 1846/37253 [00:15<04:38, 126.98it/s]
# Skipping: One of the rows is empty.
#  13%|█▎        | 4696/37253 [00:38<04:15, 127.56it/s]
# Skipping due to missing or non-string Whisper_large.
#  15%|█▌        | 5620/37253 [00:45<04:08, 127.55it/s]
# Skipping due to missing or non-string Whisper_large.
#  16%|█▌        | 5802/37253 [00:47<04:10, 125.78it/s]
# Skipping due to missing or non-string Whisper_large.
#  17%|█▋        | 6234/37253 [00:50<04:03, 127.54it/s]
# Skipping due to missing or non-string Whisper_large.
#  28%|██▊       | 10494/37253 [01:24<03:33, 125.61it/s]
# Skipping: One of the rows is empty.
#  36%|███▌      | 13333/37253 [01:46<03:07, 127.48it/s]
# Skipping due to missing or non-string Whisper_large.
#  44%|████▍     | 16504/37253 [02:11<02:39, 130.20it/s]
# Skipping due to missing or non-string Whisper_large.
#  91%|█████████▏| 34067/37253 [04:26<00:24, 131.56it/s]
# Skipping: One of the rows is empty.
#  92%|█████████▏| 34109/37253 [04:27<00:24, 130.54it/s]
# Skipping: One of the rows is empty.
#  93%|█████████▎| 34595/37253 [04:30<00:20, 130.87it/s]
# Skipping: One of the rows is empty.
# 100%|██████████| 37253/37253 [04:51<00:00, 127.95it/s]

# %%
net_aigenerated_data_whisper_large
# Out:
#        Unnamed: 0 Filename   Start_time     End_time  \
# 0               0  D0001_A  2081.540000  2109.650000
# 1               1  D0001_A   790.130000   796.580000
# 2               2  D0001_A  1562.083518  1586.220000
# 3               3  D0001_A  2016.780000  2035.673559
# 4               4  D0001_A  1682.670000  1709.110000
# ...           ...      ...          ...          ...
# 37248       37248    P0070  2586.616000  2589.346000
# 37249       37249    P0070  2782.496000  2783.706000
# 37250       37250    P0070  2995.296000  2998.116000
# 37251       37251    P0070  2604.066000  2606.656000
# 37252       37252    P0070  2434.606000  2436.576000
#
#                                            Whisper_large       WER  \
# 0      我说出来就比较的需要时间然后识别的他等你一会儿你那个话还没有说完还没有说出来的话他就取消了也...  0.247423
# 1                                               第四句有我说的话  0.500000
# 2         这部剧评分是不怎么好的因为评论区的那些人都在说男二号好惨的那个就那么情绪但是就一直输给男主角  0.312500
# 3                          很精准迅飞语音还是迅飞出手来的我记得他是叫迅飞我之前就是他  0.394737
# 4      那个是叫什么来的我忘了就是出现了另一个人然后呢他就射了一把箭然后就把那个男二号给绑杀了就是可...  0.250000
# ...                                                  ...       ...
# 37248                                         三曲循环歌曲这样而已  0.181818
# 37249                                              杨幂的电影  0.166667
# 37250                                       你好米亚今天柴油价怎么样  0.266667
# 37251                                       单曲循环歌曲 琉璃光之歌  0.166667
# 37252                                            導航到隆城民院  0.500000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count  WER_Binned  \
# 0                    1.0         6                 0        0.25
# 1                    1.0         6                 0        0.50
# 2                   10.0         6                 0        0.31
# 3                    7.0         6                 0        0.39
# 4                    8.0         6                 0        0.25
# ...                  ...       ...               ...         ...
# 37248                0.0         6                 0        0.18
# 37249                0.0         6                 0        0.17
# 37250                0.0         6                 0        0.27
# 37251                0.0         6                 0        0.17
# 37252                0.0         6                 0        0.50
#
#        rouge1-precision  rouge1-recall  rouge1-f1  rouge2-precision  \
# 0              0.916667       0.868421   0.891892          0.666667
# 1              0.800000       0.571429   0.666667          0.500000
# 2              0.880000       0.709677   0.785714          0.555556
# 3              0.733333       0.550000   0.628571          0.333333
# 4              0.833333       0.757576   0.793651          0.583333
# ...                 ...            ...        ...               ...
# 37248          0.800000       0.666667   0.727273          0.750000
# 37249          1.000000       0.750000   0.857143          1.000000
# 37250          0.833333       0.625000   0.714286          0.600000
# 37251          1.000000       0.833333   0.909091          1.000000
# 37252          0.000000       0.000000   0.000000          0.000000
#
#        rouge2-recall  rouge2-f1  rougel-precision  rougel-recall  rougel-f1
# 0           0.524590   0.587156          0.888889       0.685714   0.774194
# 1           0.333333   0.400000          0.800000       0.571429   0.666667
# 2           0.375000   0.447761          0.857143       0.571429   0.685714
# 3           0.214286   0.260870          0.631579       0.387097   0.480000
# 4           0.477273   0.525000          0.871795       0.693878   0.772727
# ...              ...        ...               ...            ...        ...
# 37248       0.600000   0.666667          0.800000       0.666667   0.727273
# 37249       0.666667   0.800000          1.000000       0.750000   0.857143
# 37250       0.375000   0.461538          0.833333       0.555556   0.666667
# 37251       0.800000   0.888889          1.000000       0.833333   0.909091
# 37252       0.000000   0.000000          0.000000       0.000000   0.000000
#
# [37253 rows x 19 columns]

# %%
# net_aigenerated_data_whisper_large.to_csv('net_aigenerated_data_whisper_large_performance_stu.csv', sep=',')

# %% [markdown]
# ***

# %% [markdown]
# ## Visualization of Relationship between Stuttering Count and Rouge Scores (Whisper Large)

# %%
## Load data from csv if starting here

net_aigenerated_data_whisper_large = pd.read_csv('/projectnb/ds549/projects/AImpower/evaluation-whisper/net_aigenerated_data_whisper_large_performance_stu.csv', delimiter=',')

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge1-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge1-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge1-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-1 vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge1-recall"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-1 vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge2-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge2-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rouge2-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-2 vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rougel-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rougel-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_large["Stutterance_Count"], 
    net_aigenerated_data_whisper_large["rougel-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-L vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlations between Stuttering and Rouge Scores (Whisper Large)

# %%
from scipy.stats import spearmanr
rho, p = spearmanr(net_aigenerated_data_whisper_large.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_large.dropna()['rouge1-precision'])
print(f"p-value [stuttering count & rouge-1 precision] = {p}")
print(f"rho [stuttering count & rouge-1 precision] = {rho}")

rho, p = spearmanr(net_aigenerated_data_whisper_large.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_large.dropna()['rouge1-recall'])
print(f"p-value [stuttering count & rouge-1 recall] = {p}")
print(f"rho [stuttering count & rouge-1 recall] = {rho}")

rho, p = spearmanr(net_aigenerated_data_whisper_large.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_large.dropna()['rouge1-f1'])
print(f"p-value [stuttering count & rouge-1 f1] = {p}")
print(f"rho [stuttering count & rouge-1 f1] = {rho}")
# Out:
# p-value [stuttering count & rouge-1 precision] = 4.859943714652352e-175
# rho [stuttering count & rouge-1 precision] = 0.14538933613395458
# p-value [stuttering count & rouge-1 recall] = 0.0
# rho [stuttering count & rouge-1 recall] = 0.3092682807876147
# p-value [stuttering count & rouge-1 f1] = 0.0
# rho [stuttering count & rouge-1 f1] = 0.27627549733913165

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# ## Importations and Data Ingestions (Whisper Tiny)

# %%
import pandas as pd
import numpy as np
import scipy
import os
from tqdm import tqdm
import re
import sys

# %%
net_data = pd.DataFrame(columns=["Filename", "Start_time", "End_time", "Transcript"]) 
net_aigenerated_data_whisper_tiny = pd.read_csv("/projectnb/ds549/projects/AImpower/datasets/generated-transcripts/Whisper_tiny.csv", delimiter=",")

del net_aigenerated_data_whisper_tiny[net_aigenerated_data_whisper_tiny.columns[0]]

# %%
for folder in os.listdir(ds_transcript_path):
    if folder == "command_stats.xlsx" or folder == "command_stats.csv":
        continue
    for audio_sample in os.listdir(os.path.join(ds_transcript_path, f"{folder}")):
        if ("_A.txt" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_A")])
        if ("_B.txt" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_B")])
        if ("P" in audio_sample):
            net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"P{folder}")])
# Out:
# /scratch/923984.1.cds/ipykernel_2925739/4285821246.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   net_data = pd.concat([net_data, pd.read_csv(os.path.join(ds_transcript_path, f"{folder}/{audio_sample}"), sep="\t", names=["Start_time", "End_time", "Transcript"]).assign(Filename=f"D{folder}_A")])

# %%
mask_pattern = r"\<.*?\>"
repetition_pattern = r"\[.*?\]"
annotation_pattern = r"/\w"


net_data = net_data.assign(Cleaned_Transcript=net_data['Transcript'].apply(lambda x: re.sub(annotation_pattern, "", re.sub(repetition_pattern, "", re.sub(mask_pattern, "", x)))))
net_data = net_data.assign(Stutterance_Count=net_data['Transcript'].apply(lambda x: len(re.findall(mask_pattern, x)) + len(re.findall(repetition_pattern, x)) + len(re.findall(annotation_pattern, x))))

# %%
net_aigenerated_data_whisper_tiny
# Out:
#       Filename   Start_time     End_time  \
# 0      D0001_A  2081.540000  2109.650000
# 1      D0001_A   790.130000   796.580000
# 2      D0001_A  1562.083518  1586.220000
# 3      D0001_A  2016.780000  2035.673559
# 4      D0001_A  1682.670000  1709.110000
# ...        ...          ...          ...
# 37248    P0070  2586.616000  2589.346000
# 37249    P0070  2782.496000  2783.706000
# 37250    P0070  2995.296000  2998.116000
# 37251    P0070  2604.066000  2606.656000
# 37252    P0070  2434.606000  2436.576000
#
#                                             Whisper_tiny
# 0      我说出来就比较不需要时间然后那个食别的他的就是他等你一会那个话还没有收完都还没有说出来的话他...
# 1                                                  在牙我收到
# 2      在不计是不怎么平分是不怎么好的就因为平分缺的那些人都在说然后我做好产的那个就那么请问但是就一...
# 3                        很精准的兴非女人还是兴非出手来的就我记得她是叫兴非我之前就是她
# 4      一个那个是叫抓来的我忘了就是出现了你那个一个人然后他就这了一把剑然后就就把那个拿到给葬撒了就...
# ...                                                  ...
# 37248                                        單許宣傳歌曲,這樣而已
# 37249                                              楊秘的電影
# 37250                                      你好米哈,今天菜油駕怎么样
# 37251                                        單取新環科曲劉旅光這個
# 37252                                            到行道龍城明月
#
# [37253 rows x 4 columns]

# %% [markdown]
# **Now we have raw data of all audio transcriptions from datasets [updated_annotation_deid_full] in `net_data` and AI predicted transcriptions in `net_aigenerated_data_whisper_tiny`**

# %% [markdown]
# ***

# %% [markdown]
# ## Whisper Tiny WER Analysis

# %%
na_count_tiny = 0
na_count_cleaned = 0

for index, row in tqdm(net_aigenerated_data_whisper_tiny.iterrows(), total=len(net_aigenerated_data_whisper_tiny)):
    
    mask_tiny = (
        (net_aigenerated_data_whisper_tiny["Filename"] == row["Filename"]) &
        (net_aigenerated_data_whisper_tiny["Start_time"] == row["Start_time"])
    )

    mask_net = (
        (net_data["Filename"] == row["Filename"]) &
        (net_data["Start_time"] == row["Start_time"])
    )

    
    tiny_row = net_aigenerated_data_whisper_tiny.loc[mask_tiny]
    net_row = net_data.loc[mask_net]

    # print(large_row)
    # print('\n\n\n\n')
    # print(net_row)
    
    if large_row.empty or net_row.empty:
        print("Skipping: One of the rows is empty.")
        continue
        
    whisper_tiny = tiny_row["Whisper_tiny"].values[0]
    cleaned_transcript = net_row["Cleaned_Transcript"].values[0]
    
    if pd.isna(whisper_large) or not isinstance(whisper_tiny, str):
        print("Skipping due to missing or non-string Whisper_tiny.")
        na_count_tiny = na_count_tiny + 1
        continue
    if pd.isna(cleaned_transcript) or not isinstance(cleaned_transcript, str):
        print("Skipping due to missing or non-string Cleaned_Transcript.")
        na_count_cleaned = na_count_cleaned + 1
        continue

    try:
        
        wer_value = wer(whisper_tiny, cleaned_transcript)
        
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "WER"] = wer_value
        
        stutterance_count = net_row["Stutterance_Count"].values[0]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "Stutterance_Count"] = stutterance_count

        # Verify assignment
        # print(f'Assigned Stutterance_Count: {stutterance_count}')
        # print(net_aigenerated_data_whisper_large.loc[mask_large, "Stutterance_Count"])

    except Exception as e:
        print(f'ERROR: {e}')
        print('Occurred with the following data:')
        print(large_row)
        print(net_row)
        
net_aigenerated_data_whisper_tiny = net_aigenerated_data_whisper_tiny.assign(NA_Count=na_count_tiny)
net_aigenerated_data_whisper_tiny = net_aigenerated_data_whisper_tiny.assign(NA_Cleaned_Count=na_count_cleaned)
# Out:
#   0%|          | 135/37253 [00:00<04:13, 146.20it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#
# 1      D0001_A   790.130000   796.580000
# 2      D0001_A  1562.083518  1586.220000
# 3      D0001_A  2016.780000  2035.673559
# 4      D0001_A  1682.670000  1709.110000
# ...        ...          ...          ...
# 37248    P0070  2586.616000  2589.346000
# 37249    P0070  2782.496000  2783.706000
# 37250    P0070  2995.296000  2998.116000
# 37251    P0070  2604.066000  2606.656000
# 37252    P0070  2434.606000  2436.576000
#
#                                             Whisper_tiny       WER  \
# 0      我说出来就比较不需要时间然后那个食别的他的就是他等你一会那个话还没有收完都还没有说出来的话他...  0.278351
# 1                                                  在牙我收到  0.800000
# 2      在不计是不怎么平分是不怎么好的就因为平分缺的那些人都在说然后我做好产的那个就那么请问但是就一...  0.437500
# 3                        很精准的兴非女人还是兴非出手来的就我记得她是叫兴非我之前就是她  0.500000
# 4      一个那个是叫抓来的我忘了就是出现了你那个一个人然后他就这了一把剑然后就就把那个拿到给葬撒了就...  0.367647
# ...                                                  ...       ...
# 37248                                        單許宣傳歌曲,這樣而已  0.727273
# 37249                                              楊秘的電影  0.666667
# 37250                                      你好米哈,今天菜油駕怎么样  0.400000
# 37251                                        單取新環科曲劉旅光這個  0.750000
# 37252                                            到行道龍城明月  0.750000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count
# 0                    1.0       332                 0
# 1                    1.0       332                 0
# 2                   10.0       332                 0
# 3                    7.0       332                 0
# 4                    8.0       332                 0
# ...                  ...       ...               ...
# 37248                0.0       332                 0
# 37249                0.0       332                 0
# 37250                0.0       332                 0
# 37251                0.0       332                 0
# 37252                0.0       332                 0
#
# [37253 rows x 8 columns]

# %%
# net_aigenerated_data_whisper_large.to_csv('net_aigenerated_data_whisper_tiny_performance_stu.csv', sep=',')

# %% [markdown]
# ***

# %% [markdown]
# ## Visualization of Relationship between Stuttering Count and Word Error Rate (Whisper Tiny)

# %%
## Load data from csv if starting here

net_aigenerated_data_whisper_tiny = pd.read_csv('/projectnb/ds549/projects/AImpower/evaluation-whisper/net_aigenerated_data_whisper_tiny_performance_stu.csv', delimiter=',')

# %%
import matplotlib.pyplot as plt

# %%
## Null value plots

nonnull_count_tiny = net_aigenerated_data_whisper_tiny["NA_Count"].count() - net_aigenerated_data_whisper_tiny.iloc[0]["NA_Count"]
null_count_tiny = net_aigenerated_data_whisper_tiny.iloc[0]["NA_Count"]

nonnull_count_cleaned = net_aigenerated_data_whisper_tiny["NA_Cleaned_Count"].count() - net_aigenerated_data_whisper_tiny.iloc[0]["NA_Cleaned_Count"]
null_count_cleaned = net_aigenerated_data_whisper_tiny.iloc[0]["NA_Cleaned_Count"]


data = {
    "NA Values": [null_count_tiny, null_count_cleaned],
    "Non NA Values": [nonnull_count_tiny, nonnull_count_cleaned],
}

species = (
    "Whisper Tiny",
    "Cleaned Ground Truth"
)

width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(2)

for na, count in data.items():
    p = ax.bar(species, count, width, label=na, bottom=bottom)
    bottom += count


ax.set_title("NA value counting", fontsize=16)
ax.set_xlabel("Source", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
ax.legend()
ax.grid(True)

plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["WER"], 
    alpha=0.7  # Handle overlapping points
)

plt.title("WER vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("WER", fontsize=14)
plt.grid(True)
plt.show()

# %%
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

net_aigenerated_data_whisper_tiny['WER_Binned'] = np.round(net_aigenerated_data_whisper_tiny['WER'], 2)

grouped_data = net_aigenerated_data_whisper_tiny.groupby(
    ['Stutterance_Count', 'WER_Binned']
).size().reset_index(name='Count')
heatmap_data = grouped_data.pivot(index='WER_Binned', columns='Stutterance_Count', values='Count').fillna(0)

plt.figure(figsize=(6, 4))
sns.heatmap(
    heatmap_data, cmap='cool', annot=False, fmt='g', cbar=True
)

plt.title("Stutterance Count vs WER (Color = Number of Cases)", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("WER (Binned)", fontsize=14)

plt.show()

# %%
from scipy.stats import spearmanr
rho, p = spearmanr(net_aigenerated_data_whisper_tiny.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_tiny.dropna()['WER'])
print(f"p-value = {p}")
print(f"rho = {rho}")
# Out:
# p-value = 0.0
# rho = -0.23094531169290533

# %% [markdown]
# ***

# %% [markdown]
# ## ROUGE-N/L Scores (Semantic Evaluation) (Whisper Tiny)

# %%
from rouge_chinese import Rouge
import jieba

# %%
rouge = Rouge()

# %%
print_ = True

for index, row in tqdm(net_aigenerated_data_whisper_tiny.iterrows(), total=len(net_aigenerated_data_whisper_tiny)):
    
    mask_tiny = (
        (net_aigenerated_data_whisper_tiny["Filename"] == row["Filename"]) &
        (net_aigenerated_data_whisper_tiny["Start_time"] == row["Start_time"])
    )

    mask_net = (
        (net_data["Filename"] == row["Filename"]) &
        (net_data["Start_time"] == row["Start_time"])
    )

    
    tiny_row = net_aigenerated_data_whisper_tiny.loc[mask_tiny]
    net_row = net_data.loc[mask_net]

    # print(large_row)
    # print('\n\n\n\n')
    # print(net_row)
    
    if tiny_row.empty or net_row.empty:
        print("Skipping: One of the rows is empty.")
        continue
        
    whisper_tiny = tiny_row["Whisper_tiny"].values[0]
    cleaned_transcript = net_row["Cleaned_Transcript"].values[0]
    
    if pd.isna(whisper_tiny) or not isinstance(whisper_tiny, str):
        print("Skipping due to missing or non-string Whisper_tiny.")
        continue
    if pd.isna(cleaned_transcript) or not isinstance(cleaned_transcript, str):
        print("Skipping due to missing or non-string Cleaned_Transcript.")
        continue

    try:
        
        scores = rouge.get_scores(' '.join(jieba.cut(whisper_tiny)), ' '.join(jieba.cut(cleaned_transcript)))
        
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge1-precision"] = scores[0]["rouge-1"]["p"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge1-recall"] = scores[0]["rouge-1"]["r"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge1-f1"] = scores[0]["rouge-1"]["f"]
        
        
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge2-precision"] = scores[0]["rouge-2"]["p"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge2-recall"] = scores[0]["rouge-2"]["r"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rouge2-f1"] = scores[0]["rouge-2"]["f"]
        
        
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rougel-precision"] = scores[0]["rouge-l"]["p"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rougel-recall"] = scores[0]["rouge-l"]["r"]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "rougel-f1"] = scores[0]["rouge-l"]["f"]
        
        stutterance_count = net_row["Stutterance_Count"].values[0]
        net_aigenerated_data_whisper_tiny.loc[mask_tiny, "Stutterance_Count"] = stutterance_count

        if (print_):
            print(net_aigenerated_data_whisper_tiny)
            print_ = False
        
        # Verify assignment
        # print(f'Assigned Stutterance_Count: {stutterance_count}')
        # print(net_aigenerated_data_whisper_tiny.loc[mask_tiny, "Stutterance_Count"])

    except Exception as e:
        print(f'ERROR: {e}')
        print('Occurred with the following data:')
        print(tiny_row)
        print(net_row)
# Out:
#   0%|          | 0/37253 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Dumping model to file cache /scratch/923984.1.cds/jieba.cache
# Loading model cost 0.562 seconds.
# Prefix dict has been built successfully.
#   0%|          | 14/37253 [00:00<27:27, 22.61it/s]
#        Unnamed: 0 Filename   Start_time     End_time  \
# 0               0  D0001_A  2081.540000  2109.650000
# 1               1  D0001_A   790.130000   796.580000
# 2               2  D0001_A  1562.083518  1586.220000
# 3               3  D0001_A  2016.780000  2035.673559
# 4               4  D0001_A  1682.670000  1709.110000
# ...           ...      ...          ...          ...
# 37248       37248    P0070  2586.616000  2589.346000
# 37249       37249    P0070  2782.496000  2783.706000
# 37250       37250    P0070  2995.296000  2998.116000
# 37251       37251    P0070  2604.066000  2606.656000
# 37252       37252    P0070  2434.606000  2436.576000
#
#                                             Whisper_tiny       WER  \
# 0      我说出来就比较不需要时间然后那个食别的他的就是他等你一会那个话还没有收完都还没有说出来的话他...  0.278351
# 1                                                  在牙我收到  0.800000
# 2      在不计是不怎么平分是不怎么好的就因为平分缺的那些人都在说然后我做好产的那个就那么请问但是就一...  0.437500
# 3                        很精准的兴非女人还是兴非出手来的就我记得她是叫兴非我之前就是她  0.500000
# 4      一个那个是叫抓来的我忘了就是出现了你那个一个人然后他就这了一把剑然后就就把那个拿到给葬撒了就...  0.367647
# ...                                                  ...       ...
# 37248                                        單許宣傳歌曲,這樣而已  0.727273
# 37249                                              楊秘的電影  0.666667
# 37250                                      你好米哈,今天菜油駕怎么样  0.400000
# 37251                                        單取新環科曲劉旅光這個  0.750000
# 37252                                            到行道龍城明月  0.750000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count  rouge1-precision  \
# 0                    1.0       332                 0              0.75
# 1                    1.0       332                 0               NaN
# 2                   10.0       332                 0               NaN
# 3                    7.0       332                 0               NaN
# 4                    8.0       332                 0               NaN
# ...                  ...       ...               ...               ...
# 37248                0.0       332                 0               NaN
# 37249                0.0       332                 0               NaN
# 37250                0.0       332                 0               NaN
# 37251                0.0       332                 0               NaN
# 37252                0.0       332                 0               NaN
#
#        rouge1-recall  rouge1-f1  rouge2-precision  rouge2-recall  rouge2-f1  \
# 0           0.710526    0.72973          0.480769       0.409836   0.442478
# 1                NaN        NaN               NaN            NaN        NaN
# 2                NaN        NaN               NaN            NaN        NaN
# 3                NaN        NaN               NaN            NaN        NaN
# 4                NaN        NaN               NaN            NaN        NaN
# ...              ...        ...               ...            ...        ...
# 37248            NaN        NaN               NaN            NaN        NaN
# 37249            NaN        NaN               NaN            NaN        NaN
# 37250            NaN        NaN               NaN            NaN        NaN
# 37251            NaN        NaN               NaN            NaN        NaN
# 37252            NaN        NaN               NaN            NaN        NaN
#
#        rougel-precision  rougel-recall  rougel-f1
# 0              0.724138            0.6    0.65625
# 1                   NaN            NaN        NaN
# 2                   NaN            NaN        NaN
# 3                   NaN            NaN        NaN
# 4                   NaN            NaN        NaN
# ...                 ...            ...        ...
# 37248               NaN            NaN        NaN
# 37249               NaN            NaN        NaN
# 37250               NaN            NaN        NaN
# 37251               NaN            NaN        NaN
# 37252               NaN            NaN        NaN
#
# [37253 rows x 18 columns]
#   0%|          | 138/37253 [00:01<04:56, 124.97it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#
/s]
# Skipping due to missing or non-string Whisper_tiny.
#  81%|████████  | 30116/37253 [03:43<00:52, 137.10it/s]
# Skipping due to missing or non-string Whisper_tiny.
#  81%|████████▏ | 30299/37253 [03:44<00:50, 138.48it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#  82%|████████▏ | 30384/37253 [03:45<00:49, 138.76it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#  82%|████████▏ | 30568/37253 [03:46<00:48, 139.20it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#  82%|████████▏ | 30611/37253 [03:46<00:47, 138.66it/s]
# Skipping due to missing or non-string Whisper_tiny.
# Skipping due to missing or non-string Whisper_tiny.
#  83%|████████▎ | 30751/37253 [03:47<00:47, 137.52it/s]
# Skipping due to missing or non-string Whisper_tiny.
#  86%|████████▌ | 31983/37253 [03:56<00:38, 136.88it/s]
# Skipping due to missing or non-string Whisper_tiny.
#  91%|█████████▏| 34070/37253 [04:11<00:23, 137.62it/s]
# Skipping: One of the rows is empty.
#  92%|█████████▏| 34098/37253 [04:12<00:22, 137.95it/s]
# Skipping: One of the rows is empty.
#  93%|█████████▎| 34588/37253 [04:15<00:19, 137.39it/s]
# Skipping: One of the rows is empty.
# 100%|██████████| 37253/37253 [04:35<00:00, 135.36it/s]

# %%
net_aigenerated_data_whisper_tiny
# Out:
#        Unnamed: 0 Filename   Start_time     End_time  \
# 0               0  D0001_A  2081.540000  2109.650000
# 1               1  D0001_A   790.130000   796.580000
# 2               2  D0001_A  1562.083518  1586.220000
# 3               3  D0001_A  2016.780000  2035.673559
# 4               4  D0001_A  1682.670000  1709.110000
# ...           ...      ...          ...          ...
# 37248       37248    P0070  2586.616000  2589.346000
# 37249       37249    P0070  2782.496000  2783.706000
# 37250       37250    P0070  2995.296000  2998.116000
# 37251       37251    P0070  2604.066000  2606.656000
# 37252       37252    P0070  2434.606000  2436.576000
#
#                                             Whisper_tiny       WER  \
# 0      我说出来就比较不需要时间然后那个食别的他的就是他等你一会那个话还没有收完都还没有说出来的话他...  0.278351
# 1                                                  在牙我收到  0.800000
# 2      在不计是不怎么平分是不怎么好的就因为平分缺的那些人都在说然后我做好产的那个就那么请问但是就一...  0.437500
# 3                        很精准的兴非女人还是兴非出手来的就我记得她是叫兴非我之前就是她  0.500000
# 4      一个那个是叫抓来的我忘了就是出现了你那个一个人然后他就这了一把剑然后就就把那个拿到给葬撒了就...  0.367647
# ...                                                  ...       ...
# 37248                                        單許宣傳歌曲,這樣而已  0.727273
# 37249                                              楊秘的電影  0.666667
# 37250                                      你好米哈,今天菜油駕怎么样  0.400000
# 37251                                        單取新環科曲劉旅光這個  0.750000
# 37252                                            到行道龍城明月  0.750000
#
#        Stutterance_Count  NA_Count  NA_Cleaned_Count  rouge1-precision  \
# 0                    1.0       332                 0          0.750000
# 1                    1.0       332                 0          0.250000
# 2                   10.0       332                 0          0.592593
# 3                    7.0       332                 0          0.687500
# 4                    8.0       332                 0          0.740741
# ...                  ...       ...               ...               ...
# 37248                0.0       332                 0          0.333333
# 37249                0.0       332                 0          0.333333
# 37250                0.0       332                 0          0.428571
# 37251                0.0       332                 0          0.000000
# 37252                0.0       332                 0          0.250000
#
#        rouge1-recall  rouge1-f1  rouge2-precision  rouge2-recall  rouge2-f1  \
# 0           0.710526   0.729730          0.480769       0.409836   0.442478
# 1           0.142857   0.181818          0.000000       0.000000   0.000000
# 2           0.516129   0.551724          0.333333       0.275000   0.301370
# 3           0.550000   0.611111          0.300000       0.214286   0.250000
# 4           0.606061   0.666667          0.378378       0.318182   0.345679
# ...              ...        ...               ...            ...        ...
# 37248       0.333333   0.333333          0.000000       0.000000   0.000000
# 37249       0.250000   0.285714          0.000000       0.000000   0.000000
# 37250       0.375000   0.400000          0.000000       0.000000   0.000000
# 37251       0.000000   0.000000          0.000000       0.000000   0.000000
# 37252       0.200000   0.222222          0.000000       0.000000   0.000000
#
#        rougel-precision  rougel-recall  rougel-f1
# 0              0.724138       0.600000   0.656250
# 1              0.250000       0.142857   0.181818
# 2              0.571429       0.476190   0.519481
# 3              0.571429       0.387097   0.461538
# 4              0.717949       0.571429   0.636364
# ...                 ...            ...        ...
# 37248          0.333333       0.333333   0.333333
# 37249          0.333333       0.250000   0.285714
# 37250          0.428571       0.333333   0.375000
# 37251          0.000000       0.000000   0.000000
# 37252          0.250000       0.200000   0.222222
#
# [37253 rows x 18 columns]

# %%
net_aigenerated_data_whisper_tiny.to_csv('net_aigenerated_data_whisper_tiny_performance_stu.csv', sep=',')

# %% [markdown]
# ***

# %% [markdown]
# ## Visualization of Relationship between Stuttering Count and Rouge Scores (Whisper Large)

# %%
## Load data from csv if starting here

net_aigenerated_data_whisper_tiny = pd.read_csv('/projectnb/ds549/projects/AImpower/evaluation-whisper/net_aigenerated_data_whisper_tiny_performance_stu.csv', delimiter=',')

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge1-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge1-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge1-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-1 vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge2-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge2-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rouge2-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-2 vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rougel-precision"], 
    facecolors="none", edgecolors='r',
    marker="8",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rougel-recall"], 
    facecolors="none", edgecolors='g',
    marker="^",
    alpha=0.7  # Handle overlapping points
)

plt.scatter(
    net_aigenerated_data_whisper_tiny["Stutterance_Count"], 
    net_aigenerated_data_whisper_tiny["rougel-f1"], 
    facecolors="none", edgecolors='b',
    marker=".",
    alpha=0.7  # Handle overlapping points
)

plt.title("Rouge-L vs Stutterance Count", fontsize=16)
plt.xlabel("Stutterance Count", fontsize=14)
plt.ylabel("Rouge Score", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlations between Stuttering and Rouge Scores (Whisper Large)

# %%
from scipy.stats import spearmanr
rho, p = spearmanr(net_aigenerated_data_whisper_tiny.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_tiny.dropna()['rouge1-precision'])
print(f"p-value [stuttering count & rouge-1 precision] = {p}")
print(f"rho [stuttering count & rouge-1 precision] = {rho}")

rho, p = spearmanr(net_aigenerated_data_whisper_tiny.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_tiny.dropna()['rouge1-recall'])
print(f"p-value [stuttering count & rouge-1 recall] = {p}")
print(f"rho [stuttering count & rouge-1 recall] = {rho}")

rho, p = spearmanr(net_aigenerated_data_whisper_tiny.dropna()['Stutterance_Count'], net_aigenerated_data_whisper_tiny.dropna()['rouge1-f1'])
print(f"p-value [stuttering count & rouge-1 f1] = {p}")
print(f"rho [stuttering count & rouge-1 f1] = {rho}")
# Out:
# p-value [stuttering count & rouge-1 precision] = 0.0
# rho [stuttering count & rouge-1 precision] = 0.36553009140497605
# p-value [stuttering count & rouge-1 recall] = 0.0
# rho [stuttering count & rouge-1 recall] = 0.38884574834080743
# p-value [stuttering count & rouge-1 f1] = 0.0
# rho [stuttering count & rouge-1 f1] = 0.3803532009602399
